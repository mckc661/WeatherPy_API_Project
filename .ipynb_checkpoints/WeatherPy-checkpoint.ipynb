# %% [markdown]
# # WeatherPy
# ----
# Observable Trends
#
# As we look at the scatter plots of the relationship between Latitude and weather patterns, the data shows some strong trends, but other charts are less clear that Latitude makes a difference.
#
# 1. The highest temperatures in the data are within the 20th Latitude.  This seems to indicate that there are hotter land masses in these latitudes whereas if there are hotter areas on the equator, there may not be as many cities in these areas.
#
# 2. Humidity seems more evenly distributed further from the equator, with the concentration for high humidity cities being between Latitude 40 and Latitude 70.
#
# 3.  Cloudiness does not seem to be affected by the proximity to the equator, with high and low levels of cloudiness evenly distributed across the latitudes.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))

# create dataframe of cities

cities_df=pd.DataFrame(cities)
# Out:
# 590

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
cities_df.columns = ['City']
cities_df
# Out:
#                  City
# 0             el alto
# 1     arraial do cabo
# 2             svetlyy
# 3            hermanus
# 4           upernavik
# 5              castro
# 6           busselton
# 7                fare
# 8           cape town
# 9               kapaa
# 10            rikitea
# 11              bluff
# 12             albany
# 13            ushuaia
# 14           zhigansk
# 15           meulaboh
# 16             hobart
# 17        grand gaube
# 18           khatanga
# 19         nanortalik
# 20            marcona
# 21       punta arenas
# 22             faanui
# 23              airai
# 24            amderma
# 25              roald
# 26     lexington park
# 27        new norfolk
# 28             mackay
# 29               hofn
# ..                ...
# 560          monrovia
# 561         meadville
# 562          paradwip
# 563              kaya
# 564         montepuez
# 565         kazalinsk
# 566             jimma
# 567            jishou
# 568      independenta
# 569      port hedland
# 570           belfort
# 571  praia da vitoria
# 572      maple valley
# 573           goundam
# 574           dolbeau
# 575         kyshtovka
# 576             sitka
# 577            gostyn
# 578      bolshoy uluy
# 579           chifeng
# 580            nagato
# 581        whitehorse
# 582         balakliya
# 583          karasjok
# 584            gilgil
# 585            polson
# 586              elko
# 587          lingyuan
# 588         barcelona
# 589           cayenne
#
# [590 rows x 1 columns]

# %%
# add 
cities_df['Latitude']=""
cities_df['Longitude']=""
cities_df['Temperature']=""
cities_df['Humidity']=""
cities_df['Wind_Speed']=""
cities_df['Cloudiness']=""
cities_df.head()
# Out:
#               City Latitude Longitude Temperature Humidity Wind_Speed  \
# 0          el alto
# 1  arraial do cabo
# 2          svetlyy
# 3         hermanus
# 4        upernavik
#
#   Cloudiness
# 0
# 1
# 2
# 3
# 4

# %%
# header command to test data on smaller subset
# cities_df=cities_df.head()

# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# use iterrows to iterate through pandas dataframe
for index, row in cities_df.iterrows():
    time.sleep(1)
    
    city= row['City']
    
# assemble url and make API request
    print(f"Retrieving Results for Index {index}:{city}.")
    response = requests.get(query_url + city).json()
    
    
    
    
# response
#     results=response['results']
    
    try:
        cities_df.loc[index, 'Latitude'] =response['coord']['lat']
        
        cities_df.loc[index, 'Longitude'] =response['coord']['lon']        
        cities_df.loc[index, 'Temperature'] =response['main']['temp_max']
        cities_df.loc[index, 'Humidity'] =response['main']['humidity']
        cities_df.loc[index, 'Wind_Speed'] =response['wind']['speed']
        cities_df.loc[index, 'Cloudiness'] =response['clouds']['all']
   
  
#         print(f"Retrieving Results for Index {cities_df}{lat}{temp}{humidity}{wind}{temp}.")

    except (KeyError, IndexError):
            print("Missing field/result... skipping.")
# Out:
# Retrieving Results for Index 0:el alto.
# Retrieving Results for Index 1:arraial do cabo.
# Retrieving Results for Index 2:svetlyy.
# Missing field/result... skipping.
# Retrieving Results for Index 3:hermanus.
# Retrieving Results for Index 4:upernavik.
# Retrieving Results for Index 5:castro.
# Retrieving Results for Index 6:busselton.
# Retrieving Results for Index 7:fare.
# Retrieving Results for Index 8:cape town.
# Retrieving Results for Index 9:kapaa.
# Retrieving Results for Index 10:rikitea.
# Retrieving Results for Index 11:bluff.
# Retrieving Results for Index 12:albany.
# Retrieving Results for Index 13:ushuaia.
# Retrieving Results for Index 14:zhigansk.
# Retrieving Results for Index 15:meulaboh.
# Retrieving Results for Index 16:hobart.
# Retrieving Results for Index 17:grand gaube.
# Retrieving Results for Index 18:khatanga.
# Retrieving Results for Index 19:nanortalik.
# Retrieving Results for Index 20:marcona.
# Missing field/result... skipping.
# Retrieving Results for Index 21:punta arenas.
# Retrieving Results for Index 22:faanui.
# Retrieving Results for Index 23:airai.
# Retrieving Results for Index 24:amderma.
# Missing field/result... skipping.
# Retrieving Results for Index 25:roald.
# Retrieving Results for Index 26:lexington park.
# Retrieving Results for Index 27:new norfolk.
# Retrieving Results for Index 28:mackay.
# Retrieving Results for Index 29:hofn.
# Retrieving Results for Index 30:fuerte.
# Retrieving Results for Index 31:mataura.
# Retrieving Results for Index 32:hun.
# Retrieving Results for Index 33:sandy bay.
# Retrieving Results for Index 34:necochea.
# Retrieving Results for Index 35:samarai.
# Retrieving Results for Index 36:westport.
# Retrieving Results for Index 37:luwuk.
# Retrieving Results for Index 38:kerema.
# Retrieving Results for Index 39:inongo.
# Retrieving Results for Index 40:ozark.
# Retrieving Results for Index 41:pucara.
# Retrieving Results for Index 42:port alfred.
# Retrieving Results for Index 43:grand river south east.
# Missing field/result... skipping.
# Retrieving Results for Index 44:flin flon.
# Retrieving Results for Index 45:yellowknife.
# Retrieving Results for Index 46:avarua.
# Retrieving Results for Index 47:luderitz.
# Retrieving Results for Index 48:jamestown.
# Retrieving Results for Index 49:kismayo.
# Missing field/result... skipping.
# Retrieving Results for Index 50:iqaluit.
# Retrieving Results for Index 51:illoqqortoormiut.
# Missing field/result... skipping.
# Retrieving Results for Index 52:atuona.
# Retrieving Results for Index 53:bambous virieux.
# Retrieving Results for Index 54:kattivakkam.
# Retrieving Results for Index 55:vzmorye.
# Missing field/result... skipping.
# Retrieving Results for Index 56:belyy yar.
# Retrieving Results for Index 57:te anau.
# Retrieving Results for Index 58:balakhta.
# Retrieving Results for Index 59:gat.
# Retrieving Results for Index 60:lomovka.
# Retrieving Results for Index 61:maneadero.
# Missing field/result... skipping.
# Retrieving Results for Index 62:banda aceh.
# Retrieving Results for Index 63:port lincoln.
# Retrieving Results for Index 64:ahipara.
# Retrieving Results for Index 65:athabasca.
# Retrieving Results for Index 66:avera.
# Retrieving Results for Index 67:kununurra.
# Retrieving Results for Index 68:mutsamudu.
# Missing field/result... skipping.
# Retrieving Results for Index 69:vaitupu.
# Missing field/result... skipping.
# Retrieving Results for Index 70:hilo.
# Retrieving Results for Index 71:aklavik.
# Retrieving Results for Index 72:ancud.
# Retrieving Results for Index 73:maun.
# Retrieving Results for Index 74:ucar.
# Retrieving Results for Index 75:tuktoyaktuk.
# Retrieving Results for Index 76:konevo.
# Retrieving Results for Index 77:erdenet.
# Retrieving Results for Index 78:lebu.
# Retrieving Results for Index 79:jalu.
# Retrieving Results for Index 80:coahuayana.
# Retrieving Results for Index 81:roxana.
# Retrieving Results for Index 82:berlevag.
# Retrieving Results for Index 83:puerto ayora.
# Retrieving Results for Index 84:bethel.
# Retrieving Results for Index 85:bathsheba.
# Retrieving Results for Index 86:coihaique.
# Retrieving Results for Index 87:chokurdakh.
# Retrieving Results for Index 88:beloha.
# Retrieving Results for Index 89:bolshoy tsaryn.
# Missing field/result... skipping.
# Retrieving Results for Index 90:tsihombe.
# Missing field/result... skipping.
# Retrieving Results for Index 91:omsukchan.
# Retrieving Results for Index 92:alyangula.
# Retrieving Results for Index 93:providencia.
# Retrieving Results for Index 94:igrim.
# Retrieving Results for Index 95:belushya guba.
# Missing field/result... skipping.
# Retrieving Results for Index 96:sentyabrskiy.
# Missing field/result... skipping.
# Retrieving Results for Index 97:cockburn town.
# Retrieving Results for Index 98:coquimbo.
# Retrieving Results for Index 99:bilibino.
# Retrieving Results for Index 100:san jose.
# Retrieving Results for Index 101:hamilton.
# Retrieving Results for Index 102:tezu.
# Retrieving Results for Index 103:saskylakh.
# Retrieving Results for Index 104:port elizabeth.
# Retrieving Results for Index 105:reconquista.
# Retrieving Results for Index 106:sfantu gheorghe.
# Retrieving Results for Index 107:wewak.
# Retrieving Results for Index 108:bredasdorp.
# Retrieving Results for Index 109:port macquarie.
# Retrieving Results for Index 110:narsaq.
# Retrieving Results for Index 111:taltal.
# Retrieving Results for Index 112:biala podlaska.
# Retrieving Results for Index 113:comodoro rivadavia.
# Retrieving Results for Index 114:vaini.
# Retrieving Results for Index 115:cervo.
# Retrieving Results for Index 116:atambua.
# Retrieving Results for Index 117:timmins.
# Retrieving Results for Index 118:los llanos de aridane.
# Retrieving Results for Index 119:attawapiskat.
# Missing field/result... skipping.
# Retrieving Results for Index 120:cidreira.
# Retrieving Results for Index 121:mahebourg.
# Retrieving Results for Index 122:evensk.
# Retrieving Results for Index 123:halifax.
# Retrieving Results for Index 124:zitose.
# Retrieving Results for Index 125:taolanaro.
# Missing field/result... skipping.
# Retrieving Results for Index 126:lasa.
# Retrieving Results for Index 127:ust-kamchatsk.
# Missing field/result... skipping.
# Retrieving Results for Index 128:mackenzie.
# Retrieving Results for Index 129:bolshiye uki.
# Missing field/result... skipping.
# Retrieving Results for Index 130:geraldton.
# Retrieving Results for Index 131:torbay.
# Retrieving Results for Index 132:nabire.
# Retrieving Results for Index 133:lavrentiya.
# Retrieving Results for Index 134:lata.
# Retrieving Results for Index 135:tibiao.
# Retrieving Results for Index 136:souillac.
# Retrieving Results for Index 137:east london.
# Retrieving Results for Index 138:barrow.
# Retrieving Results for Index 139:huarmey.
# Retrieving Results for Index 140:georgetown.
# Retrieving Results for Index 141:kloulklubed.
# Retrieving Results for Index 142:margate.
# Retrieving Results for Index 143:nemuro.
# Retrieving Results for Index 144:qesarya.
# Retrieving Results for Index 145:makubetsu.
# Retrieving Results for Index 146:noumea.
# Retrieving Results for Index 147:krasnoborsk.
# Retrieving Results for Index 148:pergamino.
# Retrieving Results for Index 149:allapalli.
# Retrieving Results for Index 150:mildura.
# Retrieving Results for Index 151:sioux lookout.
# Retrieving Results for Index 152:toliary.
# Missing field/result... skipping.
# Retrieving Results for Index 153:saleaula.
# Missing field/result... skipping.
# Retrieving Results for Index 154:ereymentau.
# Retrieving Results for Index 155:ribeira grande.
# Retrieving Results for Index 156:butaritari.
# Retrieving Results for Index 157:atar.
# Retrieving Results for Index 158:longyearbyen.
# Retrieving Results for Index 159:rio gallegos.
# Retrieving Results for Index 160:kavieng.
# Retrieving Results for Index 161:egvekinot.
# Retrieving Results for Index 162:saint-philippe.
# Retrieving Results for Index 163:bull savanna.
# Retrieving Results for Index 164:hithadhoo.
# Retrieving Results for Index 165:vao.
# Retrieving Results for Index 166:victoria.
# Retrieving Results for Index 167:beringovskiy.
# Retrieving Results for Index 168:cozumel.
# Missing field/result... skipping.
# Retrieving Results for Index 169:hoima.
# Retrieving Results for Index 170:santa maria.
# Retrieving Results for Index 171:sechura.
# Retrieving Results for Index 172:warrington.
# Retrieving Results for Index 173:saucillo.
# Retrieving Results for Index 174:san rafael.
# Retrieving Results for Index 175:nikolskoye.
# Retrieving Results for Index 176:tucurui.
# Retrieving Results for Index 177:hambantota.
# Retrieving Results for Index 178:salina.
# Retrieving Results for Index 179:ulaangom.
# Retrieving Results for Index 180:trairi.
# Retrieving Results for Index 181:uchaly.
# Retrieving Results for Index 182:cherskiy.
# Retrieving Results for Index 183:sept-iles.
# Retrieving Results for Index 184:petrove.
# Retrieving Results for Index 185:yaguajay.
# Retrieving Results for Index 186:bambanglipuro.
# Retrieving Results for Index 187:kadnikov.
# Retrieving Results for Index 188:constitucion.
# Retrieving Results for Index 189:ponta do sol.
# Retrieving Results for Index 190:fortuna.
# Retrieving Results for Index 191:provideniya.
# Retrieving Results for Index 192:ust-maya.
# Retrieving Results for Index 193:point pedro.
# Retrieving Results for Index 194:lolua.
# Missing field/result... skipping.
# Retrieving Results for Index 195:verkhoyansk.
# Retrieving Results for Index 196:leningradskiy.
# Retrieving Results for Index 197:bom jardim.
# Retrieving Results for Index 198:broome.
# Retrieving Results for Index 199:poum.
# Retrieving Results for Index 200:qaanaaq.
# Retrieving Results for Index 201:carnarvon.
# Retrieving Results for Index 202:champerico.
# Retrieving Results for Index 203:coetupo.
# Missing field/result... skipping.
# Retrieving Results for Index 204:almaty.
# Retrieving Results for Index 205:mareeba.
# Retrieving Results for Index 206:rio cauto.
# Retrieving Results for Index 207:lagoa.
# Retrieving Results for Index 208:strezhevoy.
# Retrieving Results for Index 209:nome.
# Retrieving Results for Index 210:kalga.
# Retrieving Results for Index 211:labuan.
# Retrieving Results for Index 212:puerto del rosario.
# Retrieving Results for Index 213:grindavik.
# Retrieving Results for Index 214:renqiu.
# Retrieving Results for Index 215:pozhva.
# Retrieving Results for Index 216:aykhal.
# Retrieving Results for Index 217:san cristobal.
# Retrieving Results for Index 218:talara.
# Retrieving Results for Index 219:mar del plata.
# Retrieving Results for Index 220:mergui.
# Missing field/result... skipping.
# Retrieving Results for Index 221:puerto leguizamo.
# Retrieving Results for Index 222:boulder city.
# Retrieving Results for Index 223:uzhur.
# Retrieving Results for Index 224:belaya gora.
# Retrieving Results for Index 225:inirida.
# Retrieving Results for Index 226:namibe.
# Retrieving Results for Index 227:gizo.
# Retrieving Results for Index 228:mwene-ditu.
# Retrieving Results for Index 229:barentsburg.
# Missing field/result... skipping.
# Retrieving Results for Index 230:cabo rojo.
# Retrieving Results for Index 231:kodiak.
# Retrieving Results for Index 232:alegrete.
# Retrieving Results for Index 233:langsa.
# Retrieving Results for Index 234:karsava.
# Retrieving Results for Index 235:sola.
# Retrieving Results for Index 236:anadyr.
# Retrieving Results for Index 237:muyezerskiy.
# Retrieving Results for Index 238:poole.
# Retrieving Results for Index 239:chara.
# Retrieving Results for Index 240:saint george.
# Retrieving Results for Index 241:derzhavinsk.
# Retrieving Results for Index 242:pisco.
# Retrieving Results for Index 243:sol-iletsk.
# Retrieving Results for Index 244:ambilobe.
# Retrieving Results for Index 245:vestmannaeyjar.
# Retrieving Results for Index 246:walvis bay.
# Retrieving Results for Index 247:poya.
# Retrieving Results for Index 248:henties bay.
# Retrieving Results for Index 249:ostrovnoy.
# Retrieving Results for Index 250:pevek.
# Retrieving Results for Index 251:ngunguru.
# Retrieving Results for Index 252:brumado.
# Retrieving Results for Index 253:antsohihy.
# Retrieving Results for Index 254:dikson.
# Retrieving Results for Index 255:bintulu.
# Retrieving Results for Index 256:srednekolymsk.
# Retrieving Results for Index 257:leh.
# Retrieving Results for Index 258:kupang.
# Retrieving Results for Index 259:tasiilaq.
# Retrieving Results for Index 260:synya.
# Retrieving Results for Index 261:tazovskiy.
# Retrieving Results for Index 262:petropavlovsk-kamchatskiy.
# Retrieving Results for Index 263:saint leonard.
# Retrieving Results for Index 264:golden gate.
# Retrieving Results for Index 265:piedras negras.
# Retrieving Results for Index 266:komsomolskiy.
# Retrieving Results for Index 267:arandis.
# Retrieving Results for Index 268:impfondo.
# Retrieving Results for Index 269:half moon bay.
# Retrieving Results for Index 270:nikko.
# Retrieving Results for Index 271:ponnani.
# Retrieving Results for Index 272:urfa.
# Missing field/result... skipping.
# Retrieving Results for Index 273:tabiauea.
# Missing field/result... skipping.
# Retrieving Results for Index 274:hasaki.
# Retrieving Results for Index 275:kruisfontein.
# Retrieving Results for Index 276:dawei.
# Retrieving Results for Index 277:dingle.
# Retrieving Results for Index 278:samusu.
# Missing field/result... skipping.
# Retrieving Results for Index 279:helmsdale.
# Retrieving Results for Index 280:thompson.
# Retrieving Results for Index 281:esperance.
# Retrieving Results for Index 282:klaksvik.
# Retrieving Results for Index 283:vrangel.
# Retrieving Results for Index 284:flinders.
# Retrieving Results for Index 285:manggar.
# Retrieving Results for Index 286:tromso.
# Retrieving Results for Index 287:chokwe.
# Missing field/result... skipping.
# Retrieving Results for Index 288:louisbourg.
# Missing field/result... skipping.
# Retrieving Results for Index 289:riviere-au-renard.
# Retrieving Results for Index 290:petropavlivka.
# Retrieving Results for Index 291:vardo.
# Retrieving Results for Index 292:clyde river.
# Retrieving Results for Index 293:malindi.
# Retrieving Results for Index 294:morondava.
# Retrieving Results for Index 295:altay.
# Retrieving Results for Index 296:peniche.
# Retrieving Results for Index 297:coos bay.
# Retrieving Results for Index 298:taoudenni.
# Retrieving Results for Index 299:estelle.
# Retrieving Results for Index 300:ashibetsu.
# Retrieving Results for Index 301:gangotri.
# Missing field/result... skipping.
# Retrieving Results for Index 302:nang rong.
# Retrieving Results for Index 303:dzhusaly.
# Missing field/result... skipping.
# Retrieving Results for Index 304:zonguldak.
# Retrieving Results for Index 305:semey.
# Retrieving Results for Index 306:muros.
# Retrieving Results for Index 307:cabo san lucas.
# Retrieving Results for Index 308:acapulco.
# Retrieving Results for Index 309:ondarroa.
# Retrieving Results for Index 310:sarangani.
# Retrieving Results for Index 311:karakendzha.
# Missing field/result... skipping.
# Retrieving Results for Index 312:fuling.
# Retrieving Results for Index 313:buala.
# Retrieving Results for Index 314:yanam.
# Retrieving Results for Index 315:kaeo.
# Retrieving Results for Index 316:matay.
# Retrieving Results for Index 317:talnakh.
# Retrieving Results for Index 318:husavik.
# Retrieving Results for Index 319:xichang.
# Retrieving Results for Index 320:saint-michel-des-saints.
# Retrieving Results for Index 321:pangnirtung.
# Retrieving Results for Index 322:sorland.
# Retrieving Results for Index 323:mount gambier.
# Retrieving Results for Index 324:gunnedah.
# Retrieving Results for Index 325:sarakhs.
# Retrieving Results for Index 326:san patricio.
# Retrieving Results for Index 327:zhezkazgan.
# Retrieving Results for Index 328:homer.
# Retrieving Results for Index 329:berea.
# Retrieving Results for Index 330:sao jose da coroa grande.
# Retrieving Results for Index 331:hagere selam.
# Retrieving Results for Index 332:christchurch.
# Retrieving Results for Index 333:rumoi.
# Retrieving Results for Index 334:palabuhanratu.
# Missing field/result... skipping.
# Retrieving Results for Index 335:purranque.
# Retrieving Results for Index 336:san policarpo.
# Retrieving Results for Index 337:kieta.
# Retrieving Results for Index 338:lazaro cardenas.
# Retrieving Results for Index 339:marsh harbour.
# Retrieving Results for Index 340:yerbogachen.
# Retrieving Results for Index 341:cap malheureux.
# Retrieving Results for Index 342:kizukuri.
# Retrieving Results for Index 343:edirne.
# Retrieving Results for Index 344:saldanha.
# Retrieving Results for Index 345:mandan.
# Retrieving Results for Index 346:bukoba.
# Retrieving Results for Index 347:pochinok.
# Retrieving Results for Index 348:sosnovka.
# Retrieving Results for Index 349:ilulissat.
# Retrieving Results for Index 350:ketchikan.
# Retrieving Results for Index 351:adrar.
# Retrieving Results for Index 352:novyy urgal.
# Retrieving Results for Index 353:alamogordo.
# Retrieving Results for Index 354:urubicha.
# Retrieving Results for Index 355:camacha.
# Retrieving Results for Index 356:ternate.
# Retrieving Results for Index 357:kahului.
# Retrieving Results for Index 358:aksha.
# Retrieving Results for Index 359:liepaja.
# Retrieving Results for Index 360:linhares.
# Retrieving Results for Index 361:bengkulu.
# Missing field/result... skipping.
# Retrieving Results for Index 362:karratha.
# Retrieving Results for Index 363:pushkinskiye gory.
# Retrieving Results for Index 364:jumla.
# Retrieving Results for Index 365:concepcion del uruguay.
# Retrieving Results for Index 366:sambava.
# Retrieving Results for Index 367:verkhnyaya balkariya.
# Retrieving Results for Index 368:alta floresta.
# Retrieving Results for Index 369:tawnat.
# Missing field/result... skipping.
# Retrieving Results for Index 370:lichinga.
# Retrieving Results for Index 371:lompoc.
# Retrieving Results for Index 372:tyukhtet.
# Retrieving Results for Index 373:carutapera.
# Retrieving Results for Index 374:requena.
# Retrieving Results for Index 375:mayor pablo lagerenza.
# Retrieving Results for Index 376:misratah.
# Retrieving Results for Index 377:sakaiminato.
# Retrieving Results for Index 378:rio grande.
# Retrieving Results for Index 379:sao filipe.
# Retrieving Results for Index 380:odweyne.
# Missing field/result... skipping.
# Retrieving Results for Index 381:talawdi.
# Missing field/result... skipping.
# Retrieving Results for Index 382:port blair.
# Retrieving Results for Index 383:mahon.
# Retrieving Results for Index 384:benicarlo.
# Retrieving Results for Index 385:prince george.
# Retrieving Results for Index 386:mahadday weyne.
# Missing field/result... skipping.
# Retrieving Results for Index 387:touros.
# Retrieving Results for Index 388:chivolo.
# Retrieving Results for Index 389:sao gabriel.
# Retrieving Results for Index 390:guerrero negro.
# Retrieving Results for Index 391:vitim.
# Retrieving Results for Index 392:haines junction.
# Retrieving Results for Index 393:taitung.
# Retrieving Results for Index 394:kamenka.
# Retrieving Results for Index 395:fairbanks.
# Retrieving Results for Index 396:makakilo city.
# Retrieving Results for Index 397:perth.
# Retrieving Results for Index 398:tocopilla.
# Retrieving Results for Index 399:kaharlyk.
# Retrieving Results for Index 400:alofi.
# Retrieving Results for Index 401:fez.
# Retrieving Results for Index 402:mgachi.
# Retrieving Results for Index 403:robertsport.
# Retrieving Results for Index 404:pallipattu.
# Retrieving Results for Index 405:hualmay.
# Retrieving Results for Index 406:kutum.
# Retrieving Results for Index 407:yurimaguas.
# Retrieving Results for Index 408:tiksi.
# Retrieving Results for Index 409:las vegas.
# Retrieving Results for Index 410:mys shmidta.
# Missing field/result... skipping.
# Retrieving Results for Index 411:vasai.
# Retrieving Results for Index 412:daru.
# Retrieving Results for Index 413:conde.
# Retrieving Results for Index 414:aktau.
# Retrieving Results for Index 415:kihei.
# Retrieving Results for Index 416:clifton.
# Retrieving Results for Index 417:sackville.
# Retrieving Results for Index 418:bolkhov.
# Retrieving Results for Index 419:liverpool.
# Retrieving Results for Index 420:alice springs.
# Retrieving Results for Index 421:zhangye.
# Retrieving Results for Index 422:taguatinga.
# Retrieving Results for Index 423:luis correia.
# Retrieving Results for Index 424:port augusta.
# Retrieving Results for Index 425:waddan.
# Retrieving Results for Index 426:mersing.
# Retrieving Results for Index 427:kaitangata.
# Retrieving Results for Index 428:dukat.
# Retrieving Results for Index 429:bumba.
# Retrieving Results for Index 430:havoysund.
# Retrieving Results for Index 431:codrington.
# Retrieving Results for Index 432:natal.
# Retrieving Results for Index 433:tupik.
# Retrieving Results for Index 434:wajima.
# Retrieving Results for Index 435:seoul.
# Retrieving Results for Index 436:lakatoro.
# Retrieving Results for Index 437:skarzysko-kamienna.
# Retrieving Results for Index 438:partyzany.
# Retrieving Results for Index 439:althofen.
# Retrieving Results for Index 440:acari.
# Retrieving Results for Index 441:yulara.
# Retrieving Results for Index 442:vila velha.
# Retrieving Results for Index 443:millinocket.
# Retrieving Results for Index 444:devils lake.
# Retrieving Results for Index 445:zyryanka.
# Retrieving Results for Index 446:awjilah.
# Retrieving Results for Index 447:ravar.
# Retrieving Results for Index 448:paamiut.
# Retrieving Results for Index 449:naze.
# Retrieving Results for Index 450:brae.
# Retrieving Results for Index 451:kushnarenkovo.
# Retrieving Results for Index 452:katy.
# Retrieving Results for Index 453:tumannyy.
# Missing field/result... skipping.
# Retrieving Results for Index 454:vostok.
# Retrieving Results for Index 455:villarrica.
# Retrieving Results for Index 456:sumbe.
# Retrieving Results for Index 457:edmonton.
# Retrieving Results for Index 458:severo-kurilsk.
# Retrieving Results for Index 459:riverton.
# Retrieving Results for Index 460:salalah.
# Retrieving Results for Index 461:nizhneyansk.
# Missing field/result... skipping.
# Retrieving Results for Index 462:dargaville.
# Retrieving Results for Index 463:abu samrah.
# Retrieving Results for Index 464:los andes.
# Retrieving Results for Index 465:chivay.
# Retrieving Results for Index 466:paratebueno.
# Retrieving Results for Index 467:coxim.
# Retrieving Results for Index 468:lufilufi.
# Retrieving Results for Index 469:palu.
# Retrieving Results for Index 470:cazaje.
# Missing field/result... skipping.
# Retrieving Results for Index 471:khonuu.
# Missing field/result... skipping.
# Retrieving Results for Index 472:samalaeulu.
# Missing field/result... skipping.
# Retrieving Results for Index 473:isangel.
# Retrieving Results for Index 474:simbahan.
# Retrieving Results for Index 475:oranjemund.
# Retrieving Results for Index 476:khromtau.
# Retrieving Results for Index 477:bissau.
# Retrieving Results for Index 478:dudinka.
# Retrieving Results for Index 479:marzuq.
# Retrieving Results for Index 480:eldikan.
# Missing field/result... skipping.
# Retrieving Results for Index 481:krasnogorsk.
# Retrieving Results for Index 482:barcelos.
# Retrieving Results for Index 483:am timan.
# Retrieving Results for Index 484:pori.
# Retrieving Results for Index 485:road town.
# Retrieving Results for Index 486:yozgat.
# Retrieving Results for Index 487:port hardy.
# Retrieving Results for Index 488:amahai.
# Retrieving Results for Index 489:pao de acucar.
# Retrieving Results for Index 490:bonavista.
# Retrieving Results for Index 491:santa cruz.
# Retrieving Results for Index 492:hami.
# Retrieving Results for Index 493:matara.
# Retrieving Results for Index 494:jiroft.
# Missing field/result... skipping.
# Retrieving Results for Index 495:xiongzhou.
# Retrieving Results for Index 496:morros.
# Retrieving Results for Index 497:peace river.
# Retrieving Results for Index 498:ajdabiya.
# Retrieving Results for Index 499:teguise.
# Retrieving Results for Index 500:yenagoa.
# Retrieving Results for Index 501:maniitsoq.
# Retrieving Results for Index 502:ouro preto do oeste.
# Retrieving Results for Index 503:axim.
# Retrieving Results for Index 504:havre-saint-pierre.
# Retrieving Results for Index 505:mana.
# Retrieving Results for Index 506:hammerfest.
# Retrieving Results for Index 507:hulyaypole.
# Retrieving Results for Index 508:tuatapere.
# Retrieving Results for Index 509:asau.
# Missing field/result... skipping.
# Retrieving Results for Index 510:chuy.
# Retrieving Results for Index 511:mao.
# Retrieving Results for Index 512:muli.
# Retrieving Results for Index 513:rawson.
# Retrieving Results for Index 514:alexandria.
# Retrieving Results for Index 515:mahur.
# Retrieving Results for Index 516:villeneuve-sur-lot.
# Retrieving Results for Index 517:tulagi.
# Missing field/result... skipping.
# Retrieving Results for Index 518:lira.
# Retrieving Results for Index 519:norman wells.
# Retrieving Results for Index 520:ust-kut.
# Retrieving Results for Index 521:tirumullaivasal.
# Retrieving Results for Index 522:onega.
# Retrieving Results for Index 523:juba.
# Retrieving Results for Index 524:nhulunbuy.
# Retrieving Results for Index 525:kalamazoo.
# Retrieving Results for Index 526:commerce.
# Retrieving Results for Index 527:padang.
# Retrieving Results for Index 528:katsuura.
# Retrieving Results for Index 529:maymyo.
# Retrieving Results for Index 530:rungata.
# Missing field/result... skipping.
# Retrieving Results for Index 531:zakamensk.
# Retrieving Results for Index 532:nouadhibou.
# Retrieving Results for Index 533:goderich.
# Retrieving Results for Index 534:tzaneen.
# Retrieving Results for Index 535:westpunt.
# Missing field/result... skipping.
# Retrieving Results for Index 536:tucuman.
# Retrieving Results for Index 537:vilhena.
# Retrieving Results for Index 538:luanda.
# Retrieving Results for Index 539:nacala.
# Retrieving Results for Index 540:kefalos.
# Retrieving Results for Index 541:waverley.
# Retrieving Results for Index 542:kalmunai.
# Retrieving Results for Index 543:awbari.
# Retrieving Results for Index 544:bilma.
# Retrieving Results for Index 545:asayita.
# Missing field/result... skipping.
# Retrieving Results for Index 546:preobrazheniye.
# Retrieving Results for Index 547:winnemucca.
# Retrieving Results for Index 548:winslow.
# Retrieving Results for Index 549:yeppoon.
# Retrieving Results for Index 550:puerto escondido.
# Retrieving Results for Index 551:finote selam.
# Retrieving Results for Index 552:paita.
# Retrieving Results for Index 553:nantucket.
# Retrieving Results for Index 554:borlange.
# Missing field/result... skipping.
# Retrieving Results for Index 555:mozarlandia.
# Retrieving Results for Index 556:newcastle.
# Retrieving Results for Index 557:chimay.
# Retrieving Results for Index 558:bay roberts.
# Retrieving Results for Index 559:ellisras.
# Retrieving Results for Index 560:monrovia.
# Retrieving Results for Index 561:meadville.
# Retrieving Results for Index 562:paradwip.
# Missing field/result... skipping.
# Retrieving Results for Index 563:kaya.
# Missing field/result... skipping.
# Retrieving Results for Index 564:montepuez.
# Retrieving Results for Index 565:kazalinsk.
# Missing field/result... skipping.
# Retrieving Results for Index 566:jimma.
# Retrieving Results for Index 567:jishou.
# Retrieving Results for Index 568:independenta.
# Retrieving Results for Index 569:port hedland.
# Retrieving Results for Index 570:belfort.
# Retrieving Results for Index 571:praia da vitoria.
# Retrieving Results for Index 572:maple valley.
# Retrieving Results for Index 573:goundam.
# Retrieving Results for Index 574:dolbeau.
# Missing field/result... skipping.
# Retrieving Results for Index 575:kyshtovka.
# Retrieving Results for Index 576:sitka.
# Retrieving Results for Index 577:gostyn.
# Retrieving Results for Index 578:bolshoy uluy.
# Missing field/result... skipping.
# Retrieving Results for Index 579:chifeng.
# Retrieving Results for Index 580:nagato.
# Retrieving Results for Index 581:whitehorse.
# Retrieving Results for Index 582:balakliya.
# Retrieving Results for Index 583:karasjok.
# Retrieving Results for Index 584:gilgil.
# Missing field/result... skipping.
# Retrieving Results for Index 585:polson.
# Retrieving Results for Index 586:elko.
# Retrieving Results for Index 587:lingyuan.
# Retrieving Results for Index 588:barcelona.
# Retrieving Results for Index 589:cayenne.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.to_csv(output_data_file)

cities_df
# Out:
#                  City Latitude Longitude Temperature Humidity Wind_Speed  \
# 0             el alto    -16.5    -68.19          59       16      18.34
# 1     arraial do cabo   -22.97    -42.02          77       78      11.41
# 2             svetlyy
# 3            hermanus   -34.42     19.24          59       84       5.01
# 4           upernavik    72.79    -56.15       31.55       93      13.09
# 5              castro   -42.48    -73.76        48.2       87       3.36
# 6           busselton   -33.64    115.35       46.99       68      19.08
# 7                fare    -16.7   -151.02       81.59       72       5.03
# 8           cape town   -33.93     18.42       60.01       72      17.22
# 9               kapaa    22.08   -159.32        80.6       69      11.41
# 10            rikitea   -23.12   -134.97       75.65       79      12.75
# 11              bluff   -23.58    149.07       56.57       38       8.88
# 12             albany    42.65    -73.75       78.01       40      13.87
# 13            ushuaia   -54.81    -68.31        30.2       74      11.41
# 14           zhigansk    66.77    123.37       42.17       64       9.51
# 15           meulaboh     4.14     96.13       81.59       79        6.8
# 16             hobart   -42.88    147.33        48.2       61      12.75
# 17        grand gaube   -20.01     57.66        73.4       60      10.29
# 18           khatanga    71.98    102.47       33.89       95       8.95
# 19         nanortalik    60.14    -45.24       40.91       75       5.77
# 20            marcona
# 21       punta arenas   -53.16    -70.91        37.4       55      17.22
# 22             faanui   -16.48   -151.75       82.13       73       5.61
# 23              airai    -8.93    125.41       73.67       73       7.36
# 24            amderma
# 25              roald    62.58      6.12        42.8       57       8.05
# 26     lexington park    38.26    -76.45          84       57       2.91
# 27        new norfolk   -42.78    147.06        48.2       61      12.75
# 28             mackay    53.65   -115.58        69.8       26       3.36
# 29               hofn    64.25    -15.21       30.11       81       6.26
# ..                ...      ...       ...         ...      ...        ...
# 560          monrovia     6.33     -10.8       80.33       82       8.97
# 561         meadville    41.64    -80.15       78.01       44       5.82
# 562          paradwip
# 563              kaya
# 564         montepuez   -13.13        39       67.73       79       6.42
# 565         kazalinsk
# 566             jimma     7.67     36.84       62.15       83       1.32
# 567            jishou    28.26     109.7       61.07       75       1.48
# 568      independenta    45.48     27.75        66.2       77      10.29
# 569      port hedland   -20.31    118.58        64.4       55       9.17
# 570           belfort    47.64      6.86        64.4       87       5.82
# 571  praia da vitoria    38.73    -27.07        69.8       68        8.7
# 572      maple valley    47.37   -122.04       75.99       53       3.36
# 573           goundam    16.42     -3.66       98.87       16       7.87
# 574           dolbeau
# 575         kyshtovka    56.56     76.62       55.13       60      13.65
# 576             sitka    37.17    -99.65       84.99       50         13
# 577            gostyn    51.88     17.01       64.99       72       2.24
# 578      bolshoy uluy
# 579           chifeng    42.27    118.96       50.27       45      10.09
# 580            nagato    34.35    131.14        69.8       93       3.36
# 581        whitehorse    60.72   -135.06          75       26      16.11
# 582         balakliya    49.46     36.86        64.4       63       2.24
# 583          karasjok    69.47     25.52        46.4       81       20.8
# 584            gilgil
# 585            polson    47.69   -114.16       66.99       39      10.29
# 586              elko    40.83   -115.76          45       81       9.17
# 587          lingyuan    41.24     119.4       53.33       46       8.39
# 588         barcelona    41.38      2.18          68       72       9.17
# 589           cayenne     4.94    -52.33          86       70      13.87
#
#     Cloudiness
# 0           75
# 1            0
# 2
# 3           44
# 4           89
# 5           75
# 6            0
# 7            0
# 8           20
# 9           40
# 10          99
# 11           0
# 12          75
# 13          75
# 14           0
# 15         100
# 16          75
# 17          75
# 18         100
# 19           0
# 20
# 21          75
# 22           3
# 23          99
# 24
# 25          75
# 26          75
# 27          75
# 28          20
# 29         100
# ..         ...
# 560        100
# 561         40
# 562
# 563
# 564         21
# 565
# 566         91
# 567          0
# 568         75
# 569          0
# 570         30
# 571         40
# 572          1
# 573         18
# 574
# 575         91
# 576          0
# 577          0
# 578
# 579          3
# 580         75
# 581         20
# 582          0
# 583         75
# 584
# 585         20
# 586         90
# 587          0
# 588         20
# 589         75
#
# [590 rows x 7 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# import from CSV to convert data to number format for charts
new_cities=pd.read_csv(output_data_file)

# drop empty records
new_cities=new_cities.dropna(how='any')

 # convert back to data points from DataFrame

#add statement to limit to data with Humidity below 100%
new_cities=new_cities.drop(new_cities[new_cities.Humidity >=100].index)


temp_c=new_cities['Temperature']
lat_c=new_cities['Latitude']
humid_c=new_cities['Humidity']
cloud_c=new_cities['Cloudiness']
wind_c=new_cities['Wind_Speed']

# %%
# build scatter plot for Latitude and Temperature

plt.scatter(lat_c,temp_c,facecolors='lightblue', edgecolors='black',s=35, alpha=.75)


# Incorporate the other graph properties
plt.grid()
plt.title('City Latitude vs. Max Temperature (2019)')
plt.ylabel('Max Temperature')
plt.xlabel('Latitude')



# Save Figure
plt.savefig("../Images/Temp_Latitude_Scatter.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(lat_c,humid_c,facecolors='lightblue', edgecolors='black',s=35, alpha=.75)


# Incorporate the other graph properties
plt.grid()
plt.title('City Latitude vs. Humidity (05/27/2019)')
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')



# Save Figure
plt.savefig("../Images/Humidity_Latitude_Scatter.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(lat_c,cloud_c,facecolors='lightblue', edgecolors='black',s=35, alpha=.75)


# Incorporate the other graph properties
plt.grid()
plt.title('City Latitude vs. Cloudiness (05/27/2019)')
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')



# Save Figure
plt.savefig("../Images/Cloudiness_Latitude_Scatter.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(lat_c,wind_c,facecolors='lightblue', edgecolors='black',s=35, alpha=.75)


# Incorporate the other graph properties
plt.grid()
plt.title('City Latitude vs. Wind Speed (05/27/2019)')
plt.ylabel('Wind Speed (MPH)')
plt.xlabel('Latitude')



# Save Figure
plt.savefig("../Images/Wind_Speed_Latitude_Scatter.png")
